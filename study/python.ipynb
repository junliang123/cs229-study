# %% [markdown]
# 用于python基本语法练习

# %%
def quicksort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quicksort(left) + middle + quicksort(right)

print(quicksort([3,6,8,10,1,2,1]))
# Out:
# [1, 1, 2, 3, 6, 8, 10]

# %%
hello = 'hello'
world = 'world'
print(hello)
print(len(hello))
hw = hello + ' ' + world
print(hw)
hw123 = '%s %s %d' % (hello, world, 123)
print(hw123)
# Out:
# hello
# 5
# hello world
# hello world 123

# %%
s = 'hello'
print(s.capitalize())
print(s.upper())
s = s.upper()
print(s.lower())
print(s.rjust(7))
print(s.center(7))
print(s.center(7).strip())
print(s.replace('L', '123'))
# Out:
# Hello
# HELLO
# hello
#   HELLO
#  HELLO
# HELLO
# HE123123O

# %%
animals = ['cat', 'dog', 'monkey']
for animal in animals:
    print(animal)

for idx, animal in enumerate(animals):
    print('第%d种动物叫%s' % (idx + 1, animal))

nums = [0, 1, 2, 3, 4]
even_squares = [x ** 2 for x in nums if x % 2 == 0]
print(even_squares)
# Out:
# cat
# dog
# monkey
# 第1种动物叫cat
# 第2种动物叫dog
# 第3种动物叫monkey
# [0, 4, 16]

# %%
d = {'person': 2, 'cat': 4, 'spider': 8}
for animal in d:
    leg = d[animal]
    print('一个%s有%d条腿' % (animal, leg))
for animal, leg in d.items():
    print('一个%s有%d条腿' % (animal, leg))
nums = [0, 1, 2,3 ,4]
even_square = {x: x ** 2 for x in nums if x % 2 == 0}
print(even_square)
# Out:
# 一个person有2条腿
# 一个cat有4条腿
# 一个spider有8条腿
# 一个person有2条腿
# 一个cat有4条腿
# 一个spider有8条腿
# {0: 0, 2: 4, 4: 16}

# %%
animals = {'cat', 'dog', 'monkey'}
for idx, animal in enumerate(animals):
    print('第%d种动物叫%s' % (idx + 1, animal))

from math import sqrt
nums = {int(sqrt(x)) for x in range(30)}
print(nums)
# Out:
# 第1种动物叫dog
# 第2种动物叫monkey
# 第3种动物叫cat
# {0, 1, 2, 3, 4, 5}

# %%
def hello(name, up = False):
    if up:
        print('Hello %s' % (name.upper()))
    else:
        print('Hello %s' % (name))

hello('Bob')
hello('Alice', up = True)
# Out:
# Hello Bob
# Hello ALICE

# %%
class Greeter(object):
    def __init__(self, name):
        self.name = name
    def greet(self, up = False):
        if up:
            print('Hello %s' % (self.name.upper()))
        else:
            print('Hello %s' % (self.name))
g = Greeter('Alice')
g.greet()
g.greet(up = True)
# Out:
# Hello Alice
# Hello ALICE
